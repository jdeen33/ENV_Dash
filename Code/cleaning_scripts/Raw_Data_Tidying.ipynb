# %%
import pandas as pd
import numpy as np 
import plotly.express as px
import os

# %%
for name, value in os.environ.items():
    print("{0}: {1}".format(name, value))
# Out:
# TERM_PROGRAM: Apple_Terminal
# SHELL: /bin/zsh
# TERM: xterm-color
# TMPDIR: /var/folders/wk/32c7t_hs0xzdq2mflbqy_xlm0000gn/T/
# TERM_PROGRAM_VERSION: 453
# TERM_SESSION_ID: 8C112ECA-5BBB-45A9-95E8-65342E500CD1
# USER: jdeen@middlebury.edu
# SSH_AUTH_SOCK: /private/tmp/com.apple.launchd.ESD7RTvzp1/Listeners
# PATH: /Users/jdeen@middlebury.edu/anaconda3/bin:/Users/jdeen@middlebury.edu/anaconda3/condabin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin
# __CFBundleIdentifier: com.apple.Terminal
# PWD: /Users/jdeen@middlebury.edu/Documents/ENV_Dashboard/ENV_Dash/Code/cleaning_scripts
# XPC_FLAGS: 0x0
# XPC_SERVICE_NAME: 0
# SHLVL: 1
# HOME: /Users/jdeen@middlebury.edu
# LOGNAME: jdeen@middlebury.edu
# ...

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# altair                        5.5.0
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.2
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.3.0
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# ...

# %%
comp_summary = pd.read_csv("/Users/jdeen@middlebury.edu/Documents/ENV_Dashboard/ENV_Dash/Data/Raw_Data/Scope_Summaries/comp_summary.csv",on_bad_lines= )
comp_summary
# Out:
# Skipping line 12: expected 1 fields, saw 20
# Skipping line 13: expected 1 fields, saw 5
# Skipping line 14: expected 1 fields, saw 20
# Skipping line 15: expected 1 fields, saw 5
# Skipping line 17: expected 1 fields, saw 16
# Skipping line 27: expected 1 fields, saw 20
# Skipping line 29: expected 1 fields, saw 5
# Skipping line 30: expected 1 fields, saw 20
# Skipping line 32: expected 1 fields, saw 2
# Skipping line 34: expected 1 fields, saw 19
# Skipping line 45: expected 1 fields, saw 12
# Skipping line 46: expected 1 fields, saw 17
# Skipping line 48: expected 1 fields, saw 10
# Skipping line 52: expected 1 fields, saw 5
# Skipping line 53: expected 1 fields, saw 20
# Skipping line 55: expected 1 fields, saw 6
# Skipping line 57: expected 1 fields, saw 20
#    Middlebury College Annual Greenhouse Gas Inventory: Summary Data\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t
# 0   Comprehensive Summary:\t\t\t\t\t\t\t\t\t\t\t\t...
# 1   \tFiscal Year:\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# ...
