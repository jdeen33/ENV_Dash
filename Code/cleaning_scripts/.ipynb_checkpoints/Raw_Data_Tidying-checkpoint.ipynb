# %%
import pandas as pd
import numpy as np 
import plotly.express as px
import os

# %%
for name, value in os.environ.items():
    print("{0}: {1}".format(name, value))

# %%
pip list

# %%
comp_sum = pd.read_csv("/Users/jdeen@middlebury.edu/Documents/ENV_Dashboard/ENV_Dash/Data/Raw/Summaries/Comp_Summaries.csv")
comp_sum
# Out:
#   Scope_Total_MCTDEs Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                NaN  2006_2007  2007_2008  2008_2009  2009_2010  2010_2011
# 1            Scope 1  26,957.80  28,036.60  25,290.90  16,689.20  14,505.30
# 2            Scope 2      634.8      980.3      904.6      177.2      510.6
# 3            Scope 3   1,826.00   2,221.90   1,866.40   1,969.60   2,571.20
# 4   Offsets Internal        NaN        NaN        NaN        NaN        NaN
# 5   Offsets External      864.6      595.1      660.1      539.6      551.5
# 6              Total  28,553.90  30,643.70  27,401.80  18,296.40  17,035.60
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0  2011_2012  2012_2013  2013_2014  2014_2015   2015_2016   2016_2017
# 1  14,253.40   9,638.80  10,326.00  10,122.80    8,935.50    8,023.90
# 2      436.2      858.9      891.6   1,261.40    1,356.70    1,619.20
# 3   2,854.80   3,167.20   3,835.50   3,622.10    3,429.10    4,010.00
# ...

# %%
## Transforming dataframe to start getting it into long format 

T_comp_sum= comp_sum.T

T_comp_sum
# Out:
#                             0          1         2         3  \
# Scope_Total_MCTDEs        NaN    Scope 1   Scope 2   Scope 3
# Unnamed: 1          2006_2007  26,957.80     634.8  1,826.00
# Unnamed: 2          2007_2008  28,036.60     980.3  2,221.90
# Unnamed: 3          2008_2009  25,290.90     904.6  1,866.40
# Unnamed: 4          2009_2010  16,689.20     177.2  1,969.60
# Unnamed: 5          2010_2011  14,505.30     510.6  2,571.20
# Unnamed: 6          2011_2012  14,253.40     436.2  2,854.80
# Unnamed: 7          2012_2013   9,638.80     858.9  3,167.20
# Unnamed: 8          2013_2014  10,326.00     891.6  3,835.50
# Unnamed: 9          2014_2015  10,122.80  1,261.40  3,622.10
# Unnamed: 10         2015_2016   8,935.50  1,356.70  3,429.10
# Unnamed: 11         2016_2017   8,023.90  1,619.20  4,010.00
# Unnamed: 12         2017_2018   7,855.30  1,090.50  4,028.10
# Unnamed: 13         2018_2019   7,874.40     469.3  4,193.90
# ...

# %%
## setting values from the first row (variables)to be column names

T_comp_sum.columns= T_comp_sum.iloc[0]
T_comp_sum
# Out:
# Scope_Total_MCTDEs        NaN    Scope 1   Scope 2   Scope 3  \
# Scope_Total_MCTDEs        NaN    Scope 1   Scope 2   Scope 3
# Unnamed: 1          2006_2007  26,957.80     634.8  1,826.00
# Unnamed: 2          2007_2008  28,036.60     980.3  2,221.90
# Unnamed: 3          2008_2009  25,290.90     904.6  1,866.40
# Unnamed: 4          2009_2010  16,689.20     177.2  1,969.60
# Unnamed: 5          2010_2011  14,505.30     510.6  2,571.20
# Unnamed: 6          2011_2012  14,253.40     436.2  2,854.80
# Unnamed: 7          2012_2013   9,638.80     858.9  3,167.20
# Unnamed: 8          2013_2014  10,326.00     891.6  3,835.50
# Unnamed: 9          2014_2015  10,122.80  1,261.40  3,622.10
# Unnamed: 10         2015_2016   8,935.50  1,356.70  3,429.10
# Unnamed: 11         2016_2017   8,023.90  1,619.20  4,010.00
# Unnamed: 12         2017_2018   7,855.30  1,090.50  4,028.10
# Unnamed: 13         2018_2019   7,874.40     469.3  4,193.90
# ...

# %%
T_comp_sum.drop(index=T_comp_sum.index[0], axis=0, inplace=True)

# %%
T_comp_sum
# Out:
# Scope_Total_MCTDEs        NaN    Scope 1   Scope 2   Scope 3 Offsets Internal  \
# Unnamed: 1          2006_2007  26,957.80     634.8  1,826.00              NaN
# Unnamed: 2          2007_2008  28,036.60     980.3  2,221.90              NaN
# Unnamed: 3          2008_2009  25,290.90     904.6  1,866.40              NaN
# Unnamed: 4          2009_2010  16,689.20     177.2  1,969.60              NaN
# Unnamed: 5          2010_2011  14,505.30     510.6  2,571.20              NaN
# Unnamed: 6          2011_2012  14,253.40     436.2  2,854.80              NaN
# Unnamed: 7          2012_2013   9,638.80     858.9  3,167.20              NaN
# Unnamed: 8          2013_2014  10,326.00     891.6  3,835.50              NaN
# Unnamed: 9          2014_2015  10,122.80  1,261.40  3,622.10              NaN
# Unnamed: 10         2015_2016   8,935.50  1,356.70  3,429.10                0
# Unnamed: 11         2016_2017   8,023.90  1,619.20  4,010.00        13,020.10
# ...

# %%
## renaming the NaN column to be the year by the index position 
T_comp_sum.columns.values[[0,1]]= ['Year']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 ## renaming the NaN column to be the year by the index position
# ----> 2 T_comp_sum.columns.values[[0,1]]= ['Year']
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
T_comp_sum
# Out:
# ['Year']

# %%
#resetting index to be the year 
T_comp_sum.set_index("Year")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/wk/32c7t_hs0xzdq2mflbqy_xlm0000gn/T/ipykernel_90021/2621684305.py in ?()
#       1 #resetting index to be the year
# ----> 2 T_comp_sum.set_index("Year")
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['Year'] are in the columns"
